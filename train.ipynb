# %%
# !unzip /content/sthermal.zip
# Out:
# Archive:  /content/sthermal.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/104_jpg.rf.9c1de620dd691ee662e1090399f81f85.jpg
#  extracting: test/images/105_jpg.rf.e485f72b92942d35fb473cc91de23781.jpg
#  extracting: test/images/106_jpg.rf.f272a9924250a997583197a808a64eab.jpg
#  extracting: test/images/107_jpg.rf.9c692abeff13f279c82b6f151bda6256.jpg
#  extracting: test/images/108_jpg.rf.85f60273a29b22d87c806fbcde8dd8c9.jpg
#  extracting: test/images/110_jpg.rf.32282f7210c740ee0d97ea1617295eb1.jpg
#  extracting: test/images/111_jpg.rf.7b937d1730376b0c15c7e7d5476ff91e.jpg
#  extracting: test/images/112_jpg.rf.5678949e75c3b467be545c520859b097.jpg
#  extracting: test/images/113_jpg.rf.9b4df8f6cac877a4e56ef813e865e99b.jpg
#  extracting: test/images/114_jpg.rf.e291041b3c38d087a7ea04af471f3e3d.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolo12s.pt")
results = model.train(data="/content/synthetic_thermal/data.yaml", epochs=100, imgsz=640, device=0)  # device=0 for GPU, device='cpu' for CPU
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
results = model(
    source="/content/1.png",
    save=True,
    save_txt=False,
    device=0
)
# Out:
# image 1/1 /content/1.png: 640x640 1 manunggul_jar, 16.2ms
# Speed: 3.7ms preprocess, 16.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict

# %%
# !zip -r /content/v1_model.zip /content/runs/detect/train
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch10261.jpg (deflated 8%)
#   adding: content/runs/detect/train/BoxF1_curve.png (deflated 12%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/results.csv (deflated 61%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train/train_batch10260.jpg (deflated 5%)
#   adding: content/runs/detect/train/BoxR_curve.png (deflated 14%)
#   adding: content/runs/detect/train/labels.jpg (deflated 34%)
#   adding: content/runs/detect/train/val_batch0_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 2%)
#   adding: content/runs/detect/train/val_batch2_pred.jpg (deflated 9%)
#   adding: content/runs/detect/train/results.png (deflated 7%)
# ...
